# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('C:/Users/ASUS/Desktop/p/ML/ML/Dataset/test_images/test_image.png')

# %%
cv2.imshow('qwer',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
print(img)
# Out:
# [[[195 146  98]
#   [195 146  98]
#   [195 146  98]
#   ...
#   [ 82  96  98]
#   [ 69  86  86]
#   [ 53  70  70]]
#
#  [[195 146  98]
#   [195 146  98]
#   [195 146  98]
#   ...
#   [ 74  87  89]
#   [ 71  87  88]
#   [ 66  83  83]]
#
#  [[195 146  98]
#   [195 146  98]
#   [195 146  98]
#   ...
#   [ 66  77  77]
#   [ 72  84  86]
#   [ 77  91  94]]
#
#  ...
#
#  [[177 167 155]
#   [181 170 159]
#   [183 172 161]
#   ...
#   [147 104  69]
#   [147 103  69]
#   [146 103  68]]
#
#  [[178 167 154]
#   [180 169 157]
#   [182 171 160]
#   ...
#   [147 104  69]
#   [147 104  69]
#   [147 103  69]]
#
#  [[179 167 155]
#   [180 169 157]
#   [181 171 159]
#   ...
#   [147 104  69]
#   [147 104  69]
#   [147 104  69]]]

# %%
print(img.shape)
# Out:
# (1080, 1920, 3)

# %%
plt.imshow(img)
plt.show()

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
plt.imshow(img[...,[2,1,0]])
plt.show()
